# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import math
import matplotlib.pyplot as plt

# Progress bar 
from tqdm import tqdm_notebook, tnrange

# %matplotlib inline

# %%
torch.manual_seed(1)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print(f"device:\n{device}\n")

# %% [markdown]
# # LSTM
#
# Here, we implement an LSTM from scratch in an nn.Module.
#
# Next step: we will try different approaches likes ZoneOut, drop out, weight normalization...

# %%
period_samples = 100
periods_count = 2

inputs = torch.tensor([[[math.sin(2 * math.pi * x / float(period_samples))]] for x in
                       range(period_samples * periods_count)])
print(inputs.size())

plt.plot(inputs.squeeze().numpy())
plt.show()
# Out:
# torch.Size([200, 1, 1])
